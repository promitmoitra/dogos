# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import mne
from meegkit import dss

# %%
def plot_eeg(mne_raw,pick='all',ax=None):
    if ax==None:
        fig,ax=plt.subplots()
        show=True
    if pick=='all':
        pick = mne_raw.ch_names
    for ch in pick:
        ax.plot(mne_raw.times,mne_raw.get_data(picks=ch).flatten(),label=ch)
    plt.legend()
    if show==True:
        plt.show()
    return

# %%
df = pd.read_csv('./dogos-quest-main/quest_eeg/060924-1700/Explore_84CF_ExG_ExG_stream_3.csv')
ts = np.array(df["Timestamps"])

mrk = pd.read_csv('./dogos-quest-main/quest_eeg/060924-1700/Explore_84CF_Marker_Markers_stream_1.csv')
num_events = len(mrk)
seg_len = 10

##Assuming the channels are in the order Fz, Cz, T3, T4, P3, P4, Fp1, Fp2
fz = np.array(df["Ch_1"])
cz = np.array(df["Ch_2"])
t3 = np.array(df["Ch_3"])
t4 = np.array(df["Ch_4"])
p3 = np.array(df["Ch_5"])
p4 = np.array(df["Ch_6"])

raw_np = np.array([fz,cz,t3,t4,p3,p4])/1000 #mne stores data in volts
ch_names = ['Fz','Cz','T3','T4','P3','P4']

# %%
sfreq = 1000
info = mne.create_info(ch_names,ch_types=['eeg']*len(ch_names),sfreq=sfreq,verbose=False)
raw = mne.io.RawArray(raw_np,info,verbose=False) 
raw.set_meas_date(ts[0])

annot = mne.Annotations(
    onset=mrk["Timestamps"].to_numpy()-ts[0],
    duration=[seg_len]*num_events,
    description=mrk["Ch_1"].to_list(),
    orig_time = ts[0])
raw.set_annotations(annot,verbose=False)

raw.compute_psd().plot()
plot_eeg(raw)
# Out:
# Effective window size : 2.048 (s)
# Plotting power spectral density (dB=True).
# C:\Users\promitmoitra\AppData\Local\Temp\ipykernel_9040\2703658692.py:13: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   raw.compute_psd().plot()
# C:\Users\promitmoitra\anaconda3\envs\mne\lib\site-packages\mne\viz\utils.py:158: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 1 Axes>

# %%
raw_crop = raw.copy().crop(tmax=301)
raw_crop.filter(0.01,90)

data = raw_crop.get_data()
clean, _ = dss.dss_line_iter(data.T, fline=50.2, sfreq=1000, nfft=1024)
for nf in np.arange(50.3,50.5,0.05):
    print('\nRemoving frequency:',nf)
    clean, _ = dss.dss_line_iter(clean, fline=nf, sfreq=1000, nfft=1024)
raw_crop._data = clean.T

# raw_crop.filter(None,45)
raw_crop.resample(sfreq=256,verbose=False)
raw_crop.set_eeg_reference(ref_channels='average')

raw_crop.compute_psd().plot()
plot_eeg(raw_crop)
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.01 - 90 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.01
# - Lower transition bandwidth: 0.01 Hz (-6 dB cutoff frequency: 0.01 Hz)
# - Upper passband edge: 90.00 Hz
# - Upper transition bandwidth: 22.50 Hz (-6 dB cutoff frequency: 101.25 Hz)
# - Filter length: 330001 samples (330.001 s)
# C:\Users\promitmoitra\AppData\Local\Temp\ipykernel_9040\3428987715.py:2: RuntimeWarning: filter_length (330001) is longer than the signal (301001), distortion is likely. Reduce filter length or filter a longer signal.
#   raw_crop.filter(0.01,90)
# Power of components removed by DSS: 0.20
# Iteration 0 score: -0.015203490790663732
#
# Removing frequency: 50.3
# Power of components removed by DSS: 0.16
# Iteration 0 score: -0.06420657037474416
#
# Removing frequency: 50.349999999999994
# Power of components removed by DSS: 0.01
# Iteration 0 score: 0.03907353765824779
# Power of components removed by DSS: 0.01
# Iteration 1 score: 0.02508723557510692
# Power of components removed by DSS: 0.02
# Iteration 2 score: 0.003321710205239598
# Power of components removed by DSS: 0.04
# Iteration 3 score: -0.044563791422250774
#
# Removing frequency: 50.39999999999999
# Power of components removed by DSS: 0.00
# Iteration 0 score: -3.420729192526396e-05
#
# Removing frequency: 50.44999999999999
# Power of components removed by DSS: 0.00
# Iteration 0 score: -1.8625524019586673e-05
#
# Removing frequency: 50.499999999999986
# Power of components removed by DSS: 0.00
# Iteration 0 score: -2.1768808551523043e-05
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Effective window size : 8.000 (s)
# Plotting power spectral density (dB=True).
# C:\Users\promitmoitra\AppData\Local\Temp\ipykernel_9040\3428987715.py:15: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   raw_crop.compute_psd().plot()
# C:\Users\promitmoitra\anaconda3\envs\mne\lib\site-packages\mne\viz\utils.py:158: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 1 Axes>

# %%
event_dict = mne.events_from_annotations(raw_crop)
epochs = mne.Epochs(raw_crop,event_dict[0],tmin=-2, tmax=1)

# data = epochs.get_data()
# np.shape(data.T) 
# clean, artifact = dss.dss_line_iter(data.T, fline=51, sfreq=256, nfft=1024)
# # np.shape(clean)
# epochs._data = clean.T
# epochs.decimate(4)
epochs.compute_psd().plot()
#Plot epochs to see why we are rejecting the second one
# Out:
# Used Annotations descriptions: ['sw_1']
# Not setting metadata
# 7 matching events found
# Setting baseline interval to [-2.0, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 7 events and 769 original time points ...
# 0 bad epochs dropped
#     Using multitaper spectrum estimation with 7 DPSS windows
# Plotting power spectral density (dB=True).
# Averaging across epochs before plotting...
# C:\Users\promitmoitra\AppData\Local\Temp\ipykernel_9040\1840684133.py:10: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   epochs.compute_psd().plot()
# C:\Users\promitmoitra\anaconda3\envs\mne\lib\site-packages\mne\viz\utils.py:158: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# <MNELineFigure size 1000x350 with 1 Axes>
# <MNELineFigure size 1000x350 with 1 Axes>

# %%
# chan = 'Fz'
# data = epochs.get_data(picks=chan)
# data[0].T.shape
# epochs.times.shape

# fig,ax = plt.subplots()
# for ep in range(data.shape[0]):
#     # for ch_id,ch_name in enumerate(epochs.ch_names):
#         if chan in epochs.ch_names: 
#             ax.plot(epochs.times,data[ep,0].T,label=['Epoch:'+str(ep)+' - '+chan])
#         else:
#             continue
# plt.legend()
# plt.show()

reject_mask = [False] * len(epochs)
reject_mask[1] = True
epochs.drop(reject_mask)
# Out:
# Dropped 1 epoch: 1
# <Epochs | 6 events (all good), -2 – 1 s (baseline -2 – 0 s), ~11 kB, data not loaded,
#  '1': 6>

# %%
for ch_id,ch_name in enumerate(epochs.ch_names):
    epochs.plot_image(picks=ch_name)
# Out:
# Using data from preloaded Raw for 6 events and 769 original time points ...
# Not setting metadata
# 6 matching events found
# No baseline correction applied
# 0 projection items activated
# C:\Users\promitmoitra\AppData\Local\Temp\ipykernel_9040\3714112286.py:2: RuntimeWarning: Cannot find channel coordinates in the supplied Evokeds. Not showing channel locations.
#   epochs.plot_image(picks=ch_name)
# Using data from preloaded Raw for 6 events and 769 original time points ...
# Not setting metadata
# 6 matching events found
# No baseline correction applied
# 0 projection items activated
# C:\Users\promitmoitra\AppData\Local\Temp\ipykernel_9040\3714112286.py:2: RuntimeWarning: Cannot find channel coordinates in the supplied Evokeds. Not showing channel locations.
#   epochs.plot_image(picks=ch_name)
# Using data from preloaded Raw for 6 events and 769 original time points ...
# Not setting metadata
# 6 matching events found
# No baseline correction applied
# 0 projection items activated
# C:\Users\promitmoitra\AppData\Local\Temp\ipykernel_9040\3714112286.py:2: RuntimeWarning: Cannot find channel coordinates in the supplied Evokeds. Not showing channel locations.
#   epochs.plot_image(picks=ch_name)
# Using data from preloaded Raw for 6 events and 769 original time points ...
# Not setting metadata
# 6 matching events found
# No baseline correction applied
# 0 projection items activated
# C:\Users\promitmoitra\AppData\Local\Temp\ipykernel_9040\3714112286.py:2: RuntimeWarning: Cannot find channel coordinates in the supplied Evokeds. Not showing channel locations.
#   epochs.plot_image(picks=ch_name)
# Using data from preloaded Raw for 6 events and 769 original time points ...
# Not setting metadata
# 6 matching events found
# No baseline correction applied
# 0 projection items activated
# C:\Users\promitmoitra\AppData\Local\Temp\ipykernel_9040\3714112286.py:2: RuntimeWarning: Cannot find channel coordinates in the supplied Evokeds. Not showing channel locations.
#   epochs.plot_image(picks=ch_name)
# Using data from preloaded Raw for 6 events and 769 original time points ...
# Not setting metadata
# 6 matching events found
# No baseline correction applied
# 0 projection items activated
# C:\Users\promitmoitra\AppData\Local\Temp\ipykernel_9040\3714112286.py:2: RuntimeWarning: Cannot find channel coordinates in the supplied Evokeds. Not showing channel locations.
#   epochs.plot_image(picks=ch_name)
